# %%
import pandas as pd
from functools import reduce
import numpy as np

pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
folder_path = r"Medicare Part D Spending by Drug- Excel Reports including Historical Data RY24\\"

file_1 = "Medicare Part D Spending by Drug DYT2016\\DSD_PTD_R17_DYT16_Web.xlsx"
file_2 = "Medicare Part D Spending by Drug DYT2017\\DSD_PTD_R18_DYT17_Web.xlsx"
file_3 = "Medicare Part D Spending by Drug DYT2018\\DSD_PTD_R19_DYT18_Web.xlsx"
file_4 = "Medicare Part D Spending by Drug DYT2019\\DSD_PTD_R20_DYT19_Web.xlsx"
file_5 = "Medicare Part D Spending by Drug DYT2020\\DSD_PTD_R21_DYT20_Web - 211208.xlsx"
file_6 = "Medicare Part D Spending by Drug DYT2021\\DSD_PTD_R22_DYT21_Web - 230110.xlsx"
file_7 = "Medicare Part D Spending by Drug DYT2022\\DSD_PTD_RY24_DYT22_Web - 240208.xlsx"

# %% [markdown]
# ### Process year 2016

# %%
col_names = ['Total Spending', 'Total Dosage Units', 'Total Claims', 'Total Beneficiaries',
            'Average Spending Per Dosage Unit (Weighted)', 'Average Spending Per Claim',
            'Average Spending Per Beneficiary']
no_of_cols = 7
no_of_years = 5
current_year = 2016
starting_year = current_year - 4

# Generating future column names
col_list = []
for i in range(0, (no_of_cols*no_of_years)):
    if i % no_of_cols == 0 and i != 0:
        starting_year += 1
        
    col_list.append(col_names[i%no_of_cols]+"_"+str(starting_year))

# Read the Dataframe
df_2016 = pd.read_excel(folder_path+file_1, sheet_name=1, header=3)

# Create name change dictionary
name_change_dict = {}
for i in range(0, (no_of_cols*no_of_years)):
    name_change_dict[df_2016.columns[i+3]] = col_list[i]
    
# Rename columns
df_2016.rename(name_change_dict, axis=1, inplace=True)

# Removing Brand Names leading and trailing whitespace
df_2016['Brand Name'] = df_2016['Brand Name'].apply(lambda x: x.strip())
df_2016['Generic Name'] = df_2016['Generic Name'].apply(lambda x: x.strip())

# Divide datasets
common_columns = ['Brand Name', 'Generic Name']
df_2016_2012 = df_2016.iloc[:][common_columns+[i for i in df_2016.columns if '2012' in i][:-1]]
df_2016_2013 = df_2016.iloc[:][common_columns+[i for i in df_2016.columns if '2013' in i]]
df_2016_2014 = df_2016.iloc[:][common_columns+[i for i in df_2016.columns if '2014' in i]]
df_2016_2015 = df_2016.iloc[:][common_columns+[i for i in df_2016.columns if '2015' in i][:-1]]
df_2016_2016 = df_2016.iloc[:][common_columns+[i for i in df_2016.columns if '2016' in i][:-2]]

# %% [markdown]
# ### Process year 2017

# %%
col_names = ['Total Spending', 'Total Dosage Units', 'Total Claims', 'Total Beneficiaries',
            'Average Spending Per Dosage Unit (Weighted)', 'Average Spending Per Claim',
            'Average Spending Per Beneficiary']
no_of_cols = 7
no_of_years = 5
current_year = 2017
starting_year = current_year - 4

# Generating future column names
col_list = []
for i in range(0, (no_of_cols*no_of_years)):
    if i % no_of_cols == 0 and i != 0:
        starting_year += 1
        
    col_list.append(col_names[i%no_of_cols]+"_"+str(starting_year))

# Read the Dataframe
df_2017 = pd.read_excel(folder_path+file_2, sheet_name=1, header=4)

# Create name change dictionary
name_change_dict = {}
for i in range(0, (no_of_cols*no_of_years)):
    name_change_dict[df_2017.columns[i+3]] = col_list[i]
    
# Rename columns
df_2017.rename(name_change_dict, axis=1, inplace=True)

# Removing Brand Names leading and trailing whitespace
df_2017['Brand Name'] = df_2017['Brand Name'].apply(lambda x: x.strip())
df_2017['Generic Name'] = df_2017['Generic Name'].apply(lambda x: x.strip())

# Divide datasets
common_columns = ['Brand Name', 'Generic Name']
df_2017_2013 = df_2017.iloc[:][common_columns+[i for i in df_2017.columns if '2013' in i][:-1]]
df_2017_2014 = df_2017.iloc[:][common_columns+[i for i in df_2017.columns if '2014' in i]]
df_2017_2015 = df_2017.iloc[:][common_columns+[i for i in df_2017.columns if '2015' in i]]
df_2017_2016 = df_2017.iloc[:][common_columns+[i for i in df_2017.columns if '2016' in i][:-1]]
df_2017_2017 = df_2017.iloc[:][common_columns+[i for i in df_2017.columns if '2017' in i][:-2]]

df_2017.head()
# Out:
#                        Brand Name                    Generic Name  \
# 0        1st Tier Unifine Pentips            Pen Needle, Diabetic
# 1   1st Tier Unifine Pentips Plus            Pen Needle, Diabetic
# 2                        Abacavir                Abacavir Sulfate
# 3             Abacavir-Lamivudine     Abacavir Sulfate/Lamivudine
# 4  Abacavir-Lamivudine-Zidovudine  Abacavir/Lamivudine/Zidovudine
#
#    Number of Manufacturers Total Spending_2013 Total Dosage Units_2013  \
# 0                        1            94537.70                  518920
# 1                        1
# 2                        4            26828850                 3747816
# 3                        2
# 4                        1            78230.03                    3473
#
#   Total Claims_2013 Total Beneficiaries_2013  \
# 0              4376                     1620
# 1
# 2             58827                     8346
# 3
# 4                49                       49
#
#   Average Spending Per Dosage Unit (Weighted)_2013  \
# 0                                             0.18
# 1
# 2                                             7.16
# 3
# 4                                            22.53
#
#   Average Spending Per Claim_2013 Average Spending Per Beneficiary_2013  \
# 0                           21.60                                 58.36
# 1
# 2                          456.06                               3214.58
# 3
# 4                         1596.53                               1596.53
#
#   Total Spending_2014 Total Dosage Units_2014 Total Claims_2014  \
# 0           123285.70                  677160              5620
# 1            54091.29                  269725              2275
# 2         27878290.34              4327975.99             68004
# 3
# 4         17167220.41                  766713             12201
#
#   Total Beneficiaries_2014 Average Spending Per Dosage Unit (Weighted)_2014  \
# 0                     2087                                             0.18
# 1                     1289                                             0.20
# 2                     9054                                             6.44
# 3
# 4                     1821                                            22.39
#
#   Average Spending Per Claim_2014 Average Spending Per Beneficiary_2014  \
# 0                           21.94                                 59.07
# 1                           23.78                                 41.96
# 2                          409.95                               3079.11
# 3
# 4                         1407.03                               9427.36
#
#   Total Spending_2015 Total Dosage Units_2015 Total Claims_2015  \
# 0           133958.25                  717548              5789
# 1           197091.75                  986070              7890
# 2         24504368.40                 4410978             68977
# 3
# 4         16626213.80                  759933             12216
#
#   Total Beneficiaries_2015 Average Spending Per Dosage Unit (Weighted)_2015  \
# 0                     2283                                             0.19
# 1                     4330                                             0.20
# 2                     9296                                             5.55
# 3
# 4                     1621                                            21.88
#
#   Average Spending Per Claim_2015 Average Spending Per Beneficiary_2015  \
# 0                           23.14                                 58.68
# 1                           24.98                                 45.52
# 2                          355.25                               2636.01
# 3
# 4                         1361.02                              10256.76
#
#    Total Spending_2016  Total Dosage Units_2016  Total Claims_2016  \
# 0            215930.43               1050323.00               8897
# 1            378001.19               1750607.00              14611
# 2          19337773.99               4253663.00              66526
# 3          14755782.09                439840.00              13906
# 4          12787721.57                608455.00               9768
#
#    Total Beneficiaries_2016  Average Spending Per Dosage Unit (Weighted)_2016  \
# 0                   3423.00                                              0.21
# 1                   6565.00                                              0.22
# 2                   8998.00                                              4.55
# 3                   6631.00                                             33.55
# 4                   1333.00                                             21.02
#
#    Average Spending Per Claim_2016 Average Spending Per Beneficiary_2016  \
# 0                            24.27                                 63.08
# 1                            25.87                                 57.58
# 2                           290.68                               2149.12
# 3                          1061.11                               2225.27
# 4                          1309.14                               9593.19
#
#    Total Spending_2017  Total Dosage Units_2017  Total Claims_2017  \
# 0            217626.40               1012618.00               8582
# 1            402383.65               1851903.00              15414
# 2          16159350.36               3780784.00              58678
# 3          36163620.28               1542971.00              49336
# 4          10164840.09                468641.00               7454
#
#    Total Beneficiaries_2017  Average Spending Per Dosage Unit (Weighted)_2017  \
# 0                   3020.00                                              0.22
# 1                   5974.00                                              0.22
# 2                   8022.00                                              4.29
# 3                   9471.00                                             23.41
# 4                    973.00                                             21.69
#
#    Average Spending Per Claim_2017 Average Spending Per Beneficiary_2017  \
# 0                            25.36                                 72.06
# 1                            26.11                                 67.36
# 2                           275.39                               2014.38
# 3                           733.01                               3818.35
# 4                          1363.68                              10446.91
#
#    Change in Average Spending Per Dosage Unit (2016-2017)  \
# 0                                               0.04
# 1                                               0.01
# 2                                              -0.06
# 3                                              -0.30
# 4                                               0.03
#
#    Annual Growth Rate in Average Spending Per Dosage Unit (2013-2017)
# 0                                               0.04
# 1                                               0.03
# 2                                              -0.12
# 3                                              -0.30
# 4                                              -0.01

# %% [markdown]
# ### Process year 2018

# %%
col_names = ['Total Spending', 'Total Dosage Units', 'Total Claims', 'Total Beneficiaries',
            'Average Spending Per Dosage Unit (Weighted)', 'Average Spending Per Claim',
            'Average Spending Per Beneficiary', 'Outlier Flag']
no_of_cols = 8
no_of_years = 5
current_year = 2018
starting_year = current_year - 4

# Generating future column names
col_list = []
for i in range(0, (no_of_cols*no_of_years)):
    if i % no_of_cols == 0 and i != 0:
        starting_year += 1
        
    col_list.append(col_names[i%no_of_cols]+"_"+str(starting_year))

# Read the Dataframe
df_2018 = pd.read_excel(folder_path+file_3, sheet_name=1, header=3)

# Create name change dictionary
name_change_dict = {}
for i in range(0, (no_of_cols*no_of_years)):
    name_change_dict[df_2018.columns[i+3]] = col_list[i]
    
# Rename columns
df_2018.rename(name_change_dict, axis=1, inplace=True)

# Removing Brand Names leading and trailing whitespace
df_2018['Brand Name'] = df_2018['Brand Name'].apply(lambda x: x.strip())
df_2018['Generic Name'] = df_2018['Generic Name'].apply(lambda x: x.strip())

# Divide datasets
common_columns = ['Brand Name', 'Generic Name']
df_2018_2014 = df_2018.iloc[:][common_columns+[i for i in df_2018.columns if '2014' in i][:-1]]
df_2018_2015 = df_2018.iloc[:][common_columns+[i for i in df_2018.columns if '2015' in i]]
df_2018_2016 = df_2018.iloc[:][common_columns+[i for i in df_2018.columns if '2016' in i]]
df_2018_2017 = df_2018.iloc[:][common_columns+[i for i in df_2018.columns if '2017' in i][:-1]]
df_2018_2018 = df_2018.iloc[:][common_columns+[i for i in df_2018.columns if '2018' in i][:-2]]

df_2018.head()
# Out:
#                        Brand Name                    Generic Name  \
# 0        1st Tier Unifine Pentips            Pen Needle, Diabetic
# 1   1st Tier Unifine Pentips Plus            Pen Needle, Diabetic
# 2                        Abacavir                Abacavir Sulfate
# 3             Abacavir-Lamivudine     Abacavir Sulfate/Lamivudine
# 4  Abacavir-Lamivudine-Zidovudine  Abacavir/Lamivudine/Zidovudine
#
#    Number of Manufacturers Total Spending_2014 Total Dosage Units_2014  \
# 0                        1           123941.34                  680820
# 1                        1            54091.29                  269725
# 2                        9         27941765.03              4337914.99
# 3                        5
# 4                        1         17167220.41                  766713
#
#   Total Claims_2014 Total Beneficiaries_2014  \
# 0              5650                     2097
# 1              2275                     1289
# 2             68187                     9076
# 3
# 4             12201                     1821
#
#   Average Spending Per Dosage Unit (Weighted)_2014  \
# 0                                             0.18
# 1                                             0.20
# 2                                             6.44
# 3
# 4                                            22.39
#
#   Average Spending Per Claim_2014 Average Spending Per Beneficiary_2014  \
# 0                           21.94                                 59.10
# 1                           23.78                                 41.96
# 2                          409.78                               3078.64
# 3
# 4                         1407.03                               9427.36
#
#   Outlier Flag_2014 Total Spending_2015 Total Dosage Units_2015  \
# 0                 0           134200.53                  718948
# 1                 0           197091.75                  986070
# 2                 0         24563907.10                 4421534
# 3
# 4                 0         16626213.80                  759933
#
#   Total Claims_2015 Total Beneficiaries_2015  \
# 0              5802                     2290
# 1              7890                     4330
# 2             69168                     9319
# 3
# 4             12216                     1621
#
#   Average Spending Per Dosage Unit (Weighted)_2015  \
# 0                                             0.19
# 1                                             0.20
# 2                                             5.56
# 3
# 4                                            21.88
#
#   Average Spending Per Claim_2015 Average Spending Per Beneficiary_2015  \
# 0                           23.13                                 58.60
# 1                           24.98                                 45.52
# 2                          355.13                               2635.90
# 3
# 4                         1361.02                              10256.76
#
#   Outlier Flag_2015 Total Spending_2016 Total Dosage Units_2016  \
# 0                 0           216273.87                 1052113
# 1                 0           378148.31                 1751507
# 2                 0         19363103.82                 4259148
# 3                           14755782.09                  439840
# 4                 0         12787721.57                  608455
#
#   Total Claims_2016 Total Beneficiaries_2016  \
# 0              8913                     3428
# 1             14616                     6566
# 2             66624                     9011
# 3             13906                     6631
# 4              9768                     1333
#
#   Average Spending Per Dosage Unit (Weighted)_2016  \
# 0                                             0.21
# 1                                             0.22
# 2                                             4.55
# 3                                            33.55
# 4                                            21.02
#
#   Average Spending Per Claim_2016 Average Spending Per Beneficiary_2016  \
# 0                           24.26                                 63.09
# 1                           25.87                                 57.59
# 2                          290.63                               2148.83
# 3                         1061.11                               2225.27
# 4                         1309.14                               9593.19
#
#   Outlier Flag_2016 Total Spending_2017 Total Dosage Units_2017  \
# 0                 0           217990.68                 1014518
# 1                 0           402449.01                 1852203
# 2                 0         16810136.86                 3990880
# 3                 0         51270992.60                 2504950
# 4                 0         10164840.09                  468641
#
#   Total Claims_2017 Total Beneficiaries_2017  \
# 0              8597                     3026
# 1             15417                     5975
# 2             60902                     8101
# 3             80686                    10479
# 4              7454                      973
#
#   Average Spending Per Dosage Unit (Weighted)_2017  \
# 0                                             0.22
# 1                                             0.22
# 2                                             4.29
# 3                                            20.42
# 4                                            21.69
#
#   Average Spending Per Claim_2017 Average Spending Per Beneficiary_2017  \
# 0                           25.36                                 72.04
# 1                           26.10                                 67.36
# 2                          276.02                               2075.07
# 3                          635.44                               4892.74
# 4                         1363.68                              10446.91
#
#   Outlier Flag_2017  Total Spending_2018  Total Dosage Units_2018  \
# 0                 0            167193.78                761658.00
# 1                 0            369416.83               1814008.00
# 2                 0          14479715.39               3972983.00
# 3                 0          24587440.48               2225584.00
# 4                 0           6955321.12                330735.00
#
#    Total Claims_2018 Total Beneficiaries_2018  \
# 0               6538                     2341
# 1              14932                     5675
# 2              54467                     7359
# 3              70494                     8684
# 4               5298                      710
#
#    Average Spending Per Dosage Unit (Weighted)_2018  \
# 0                                              0.22
# 1                                              0.20
# 2                                              4.04
# 3                                             11.06
# 4                                             21.03
#
#    Average Spending Per Claim_2018 Average Spending Per Beneficiary_2018  \
# 0                            25.57                                 71.42
# 1                            24.74                                 65.10
# 2                           265.84                               1967.62
# 3                           348.79                               2831.35
# 4                          1312.82                               9796.23
#
#   Outlier Flag_2018 Change in Average Spending Per Dosage Unit (2017-2018)  \
# 0                 0                                               0.02
# 1                 0                                              -0.06
# 2                 0                                              -0.06
# 3                 1                                              -0.46
# 4                 0                                              -0.03
#
#   Annual Growth Rate in Average Spending Per Dosage Unit (2014-2018)
# 0                                               0.05
# 1                                               0.00
# 2                                              -0.11
# 3                                              -0.43
# 4                                              -0.02

# %% [markdown]
# ### Process year 2019

# %%
col_names = ['Total Spending', 'Total Dosage Units', 'Total Claims', 'Total Beneficiaries',
            'Average Spending Per Dosage Unit (Weighted)', 'Average Spending Per Claim',
            'Average Spending Per Beneficiary', 'Outlier Flag']
no_of_cols = 8
no_of_years = 5
current_year = 2019
starting_year = current_year - 4

# Generating future column names
col_list = []
for i in range(0, (no_of_cols*no_of_years)):
    if i % no_of_cols == 0 and i != 0:
        starting_year += 1
        
    col_list.append(col_names[i%no_of_cols]+"_"+str(starting_year))

# Read the Dataframe
df_2019 = pd.read_excel(folder_path+file_4, sheet_name=1, header=3)

# Create name change dictionary
name_change_dict = {}
for i in range(0, (no_of_cols*no_of_years)):
    name_change_dict[df_2019.columns[i+3]] = col_list[i]
    
# Rename columns
df_2019.rename(name_change_dict, axis=1, inplace=True)

# Removing Brand Names leading and trailing whitespace
df_2019['Brand Name'] = df_2019['Brand Name'].apply(lambda x: x.strip())
df_2019['Generic Name'] = df_2019['Generic Name'].apply(lambda x: x.strip())

# Divide datasets
common_columns = ['Brand Name', 'Generic Name']
df_2019_2015 = df_2019.iloc[:][common_columns+[i for i in df_2019.columns if '2015' in i][:-1]]
df_2019_2016 = df_2019.iloc[:][common_columns+[i for i in df_2019.columns if '2016' in i]]
df_2019_2017 = df_2019.iloc[:][common_columns+[i for i in df_2019.columns if '2017' in i]]
df_2019_2018 = df_2019.iloc[:][common_columns+[i for i in df_2019.columns if '2018' in i][:-1]]
df_2019_2019 = df_2019.iloc[:][common_columns+[i for i in df_2019.columns if '2019' in i][:-2]]

df_2019.head()
# Out:
#                        Brand Name                    Generic Name  \
# 0        1st Tier Unifine Pentips            Pen Needle, Diabetic
# 1   1st Tier Unifine Pentips Plus            Pen Needle, Diabetic
# 2                        Abacavir                Abacavir Sulfate
# 3             Abacavir-Lamivudine     Abacavir Sulfate/Lamivudine
# 4  Abacavir-Lamivudine-Zidovudine  Abacavir/Lamivudine/Zidovudine
#
#    Number of Manufacturers Total Spending_2015 Total Dosage Units_2015  \
# 0                        1           134200.53                  718948
# 1                        1           197091.75                  986070
# 2                        9         24519295.76                 4413607
# 3                        6
# 4                        1         16626213.80                  759933
#
#   Total Claims_2015 Total Beneficiaries_2015  \
# 0              5802                     2290
# 1              7889                     4330
# 2             69019                     9319
# 3
# 4             12216                     1621
#
#   Average Spending Per Dosage Unit (Weighted)_2015  \
# 0                                             0.19
# 1                                             0.20
# 2                                             5.56
# 3
# 4                                            21.88
#
#   Average Spending Per Claim_2015 Average Spending Per Beneficiary_2015  \
# 0                           23.13                                 58.60
# 1                           24.98                                 45.52
# 2                          355.25                               2631.11
# 3
# 4                         1361.02                              10256.76
#
#   Outlier Flag_2015 Total Spending_2016 Total Dosage Units_2016  \
# 0                 0           216273.87                 1052113
# 1                 0           378148.31                 1751507
# 2                 0         19358627.55                 4257534
# 3                           14755782.09                  439840
# 4                 0         12787721.57                  608455
#
#   Total Claims_2016 Total Beneficiaries_2016  \
# 0              8911                     3428
# 1             14615                     6566
# 2             66599                     9011
# 3             13905                     6631
# 4              9765                     1333
#
#   Average Spending Per Dosage Unit (Weighted)_2016  \
# 0                                             0.21
# 1                                             0.22
# 2                                             4.55
# 3                                            33.55
# 4                                            21.02
#
#   Average Spending Per Claim_2016 Average Spending Per Beneficiary_2016  \
# 0                           24.27                                 63.09
# 1                           25.87                                 57.59
# 2                          290.67                               2148.33
# 3                         1061.19                               2225.27
# 4                         1309.55                               9593.19
#
#   Outlier Flag_2016 Total Spending_2017 Total Dosage Units_2017  \
# 0                 0           217990.68                 1014518
# 1                 0           402449.01                 1852203
# 2                 0         16815197.53                 3991061
# 3                 0         51270992.60                 2504950
# 4                 0         10164840.09                  468641
#
#   Total Claims_2017 Total Beneficiaries_2017  \
# 0              8597                     3026
# 1             15413                     5975
# 2             60900                     8101
# 3             80677                    10479
# 4              7454                      973
#
#   Average Spending Per Dosage Unit (Weighted)_2017  \
# 0                                             0.22
# 1                                             0.22
# 2                                             4.30
# 3                                            20.42
# 4                                            21.69
#
#   Average Spending Per Claim_2017 Average Spending Per Beneficiary_2017  \
# 0                           25.36                                 72.04
# 1                           26.11                                 67.36
# 2                          276.11                               2075.69
# 3                          635.51                               4892.74
# 4                         1363.68                              10446.91
#
#   Outlier Flag_2017 Total Spending_2018 Total Dosage Units_2018  \
# 0                 0           167193.78                  761658
# 1                 0           369416.83                 1814008
# 2                 0         14476732.05                 3971677
# 3                 0         24587440.48                 2225584
# 4                 0          6955321.12                  330735
#
#   Total Claims_2018 Total Beneficiaries_2018  \
# 0              6537                     2341
# 1             14932                     5675
# 2             54433                     7359
# 3             70484                     8684
# 4              5298                      710
#
#   Average Spending Per Dosage Unit (Weighted)_2018  \
# 0                                             0.22
# 1                                             0.20
# 2                                             4.04
# 3                                            11.06
# 4                                            21.03
#
#   Average Spending Per Claim_2018 Average Spending Per Beneficiary_2018  \
# 0                           25.58                                 71.42
# 1                           24.74                                 65.10
# 2                          265.96                               1967.21
# 3                          348.84                               2831.35
# 4                         1312.82                               9796.23
#
#   Outlier Flag_2018  Total Spending_2019  Total Dosage Units_2019  \
# 0                 0            139201.68                642471.00
# 1                 0            343031.42               1830596.00
# 2                 0          10518349.87               3423584.00
# 3                 1          19441270.39               1693617.00
# 4                 0           4849598.99                225020.00
#
#    Total Claims_2019 Total Beneficiaries_2019  \
# 0               5392                     1878
# 1              14581                     5319
# 2              44269                     6085
# 3              50231                     6423
# 4               3648                      493
#
#    Average Spending Per Dosage Unit (Weighted)_2019  \
# 0                                              0.22
# 1                                              0.19
# 2                                              3.49
# 3                                             11.47
# 4                                             21.55
#
#    Average Spending Per Claim_2019 Average Spending Per Beneficiary_2019  \
# 0                            25.82                                 74.12
# 1                            23.53                                 64.49
# 2                           237.60                               1728.57
# 3                           387.04                               3026.82
# 4                          1329.39                               9836.91
#
#   Outlier Flag_2019 Change in Average Spending Per Dosage Unit (2018-2019)  \
# 0                 0                                              -0.01
# 1                 0                                              -0.08
# 2                 0                                              -0.14
# 3                 0                                               0.04
# 4                 0                                               0.02
#
#   Annual Growth Rate in Average Spending Per Dosage Unit (2015-2019)
# 0                                               0.04
# 1                                              -0.02
# 2                                              -0.11
# 3                                              -0.30
# 4                                              -0.00

# %% [markdown]
# ### Process year 2020

# %%
col_names = ['Total Spending', 'Total Dosage Units', 'Total Claims', 'Total Beneficiaries',
            'Average Spending Per Dosage Unit (Weighted)', 'Average Spending Per Claim',
            'Average Spending Per Beneficiary', 'Outlier Flag']
no_of_cols = 8
no_of_years = 5
current_year = 2020
starting_year = current_year - 4

# Generating future column names
col_list = []
for i in range(0, (no_of_cols*no_of_years)):
    if i % no_of_cols == 0 and i != 0:
        starting_year += 1
        
    col_list.append(col_names[i%no_of_cols]+"_"+str(starting_year))

# Read the Dataframe
df_2020 = pd.read_excel(folder_path+file_5, sheet_name=1, header=3)

# Create name change dictionary
name_change_dict = {}
for i in range(0, (no_of_cols*no_of_years)):
    name_change_dict[df_2020.columns[i+3]] = col_list[i]
    
# Rename columns
df_2020.rename(name_change_dict, axis=1, inplace=True)

# Removing Brand Names leading and trailing whitespace
df_2020['Brand Name'] = df_2020['Brand Name'].apply(lambda x: x.strip())
df_2020['Generic Name'] = df_2020['Generic Name'].apply(lambda x: x.strip())

# Divide datasets
common_columns = ['Brand Name', 'Generic Name']
df_2020_2016 = df_2020.iloc[:][common_columns+[i for i in df_2020.columns if '2016' in i][:-1]]
df_2020_2017 = df_2020.iloc[:][common_columns+[i for i in df_2020.columns if '2017' in i]]
df_2020_2018 = df_2020.iloc[:][common_columns+[i for i in df_2020.columns if '2018' in i]]
df_2020_2019 = df_2020.iloc[:][common_columns+[i for i in df_2020.columns if '2019' in i][:-1]]
df_2020_2020 = df_2020.iloc[:][common_columns+[i for i in df_2020.columns if '2020' in i][:-2]]

df_2020.head()
# Out:
#                        Brand Name                    Generic Name  \
# 0        1st Tier Unifine Pentips            Pen Needle, Diabetic
# 1   1st Tier Unifine Pentips Plus            Pen Needle, Diabetic
# 2                        Abacavir                Abacavir Sulfate
# 3             Abacavir-Lamivudine     Abacavir Sulfate/Lamivudine
# 4  Abacavir-Lamivudine-Zidovudine  Abacavir/Lamivudine/Zidovudine
#
#    Number of Manufacturers Total Spending_2016 Total Dosage Units_2016  \
# 0                        1           216273.87                 1052113
# 1                        1           378040.97                 1750907
# 2                        8         19337054.97                 4253483
# 3                        6         14755782.09                  439840
# 4                        1         12787721.57                  608455
#
#   Total Claims_2016 Total Beneficiaries_2016  \
# 0              8913                     3428
# 1             14610                     6564
# 2             66523                     9008
# 3             13906                     6631
# 4              9768                     1333
#
#   Average Spending Per Dosage Unit (Weighted)_2016  \
# 0                                             0.21
# 1                                             0.22
# 2                                             4.55
# 3                                            33.55
# 4                                            21.02
#
#   Average Spending Per Claim_2016 Average Spending Per Beneficiary_2016  \
# 0                           24.26                                 63.09
# 1                           25.88                                 57.59
# 2                          290.68                               2146.65
# 3                         1061.11                               2225.27
# 4                         1309.14                               9593.19
#
#   Outlier Flag_2016 Total Spending_2017 Total Dosage Units_2017  \
# 0                 0           217938.04                 1014318
# 1                 0           402124.68                 1850703
# 2                 0         16793969.54                 3985804
# 3                 0         51251796.33                 2503870
# 4                 0         10158493.71                  468341
#
#   Total Claims_2017 Total Beneficiaries_2017  \
# 0              8595                     3025
# 1             15403                     5967
# 2             60831                     8090
# 3             80654                    10465
# 4              7451                      971
#
#   Average Spending Per Dosage Unit (Weighted)_2017  \
# 0                                             0.22
# 1                                             0.22
# 2                                             4.29
# 3                                            20.42
# 4                                            21.69
#
#   Average Spending Per Claim_2017 Average Spending Per Beneficiary_2017  \
# 0                           25.36                                 72.05
# 1                           26.11                                 67.39
# 2                          276.08                               2075.89
# 3                          635.45                               4897.45
# 4                         1363.37                              10461.89
#
#   Outlier Flag_2017 Total Spending_2018 Total Dosage Units_2018  \
# 0                 0           167193.78                  761658
# 1                 0           369402.85                 1813908
# 2                 0         14476732.05                 3971677
# 3                 0         24580930.14                 2224864
# 4                 0          6955321.12                  330735
#
#   Total Claims_2018 Total Beneficiaries_2018  \
# 0              6538                     2341
# 1             14931                     5674
# 2             54438                     7359
# 3             70470                     8681
# 4              5298                      710
#
#   Average Spending Per Dosage Unit (Weighted)_2018  \
# 0                                             0.22
# 1                                             0.20
# 2                                             4.04
# 3                                            11.06
# 4                                            21.03
#
#   Average Spending Per Claim_2018 Average Spending Per Beneficiary_2018  \
# 0                           25.57                                 71.42
# 1                           24.74                                 65.10
# 2                          265.93                               1967.21
# 3                          348.81                               2831.58
# 4                         1312.82                               9796.23
#
#   Outlier Flag_2018 Total Spending_2019 Total Dosage Units_2019  \
# 0                 0           139201.68                  642471
# 1                 0           343031.42                 1830596
# 2                 0         10511827.27                 3422308
# 3                 1         19441270.39                 1693617
# 4                 0          4849598.99                  225020
#
#   Total Claims_2019 Total Beneficiaries_2019  \
# 0              5392                     1878
# 1             14581                     5319
# 2             44259                     6085
# 3             50235                     6423
# 4              3648                      493
#
#   Average Spending Per Dosage Unit (Weighted)_2019  \
# 0                                             0.22
# 1                                             0.19
# 2                                             3.49
# 3                                            11.47
# 4                                            21.55
#
#   Average Spending Per Claim_2019 Average Spending Per Beneficiary_2019  \
# 0                           25.82                                 74.12
# 1                           23.53                                 64.49
# 2                          237.51                               1727.50
# 3                          387.01                               3026.82
# 4                         1329.39                               9836.91
#
#   Outlier Flag_2019  Total Spending_2020  Total Dosage Units_2020  \
# 0                 0            118923.24                547006.00
# 1                 0            210217.15               1046616.00
# 2                 0           9241054.74               2972406.00
# 3                 0          14847197.71               1379151.00
# 4                 0           2085404.63                 96333.00
#
#    Total Claims_2020 Total Beneficiaries_2020  \
# 0               4457                     1595
# 1               8408                     3905
# 2              37325                     5068
# 3              37758                     4752
# 4               1585                      290
#
#    Average Spending Per Dosage Unit (Weighted)_2020  \
# 0                                              0.22
# 1                                              0.20
# 2                                              3.49
# 3                                             10.78
# 4                                             21.65
#
#    Average Spending Per Claim_2020 Average Spending Per Beneficiary_2020  \
# 0                            26.68                                 74.56
# 1                            25.00                                 53.83
# 2                           247.58                               1823.41
# 3                           393.22                               3124.41
# 4                          1315.71                               7191.05
#
#    Outlier Flag_2020 Change in Average Spending Per Dosage Unit (2019-2020)  \
# 0                  0                                               0.00
# 1                  0                                               0.07
# 2                  0                                              -0.00
# 3                  0                                              -0.06
# 4                  0                                               0.00
#
#   Annual Growth Rate in Average Spending Per Dosage Unit (2016-2020)
# 0                                               0.01
# 1                                              -0.02
# 2                                              -0.06
# 3                                              -0.25
# 4                                               0.01

# %% [markdown]
# ### Process year 2021

# %%
col_names = ['Total Spending', 'Total Dosage Units', 'Total Claims', 'Total Beneficiaries',
            'Average Spending Per Dosage Unit (Weighted)', 'Average Spending Per Claim',
            'Average Spending Per Beneficiary', 'Outlier Flag']
no_of_cols = 8
no_of_years = 5
current_year = 2021
starting_year = current_year - 4

# Generating future column names
col_list = []
for i in range(0, (no_of_cols*no_of_years)):
    if i % no_of_cols == 0 and i != 0:
        starting_year += 1
        
    col_list.append(col_names[i%no_of_cols]+"_"+str(starting_year))

# Read the Dataframe
df_2021 = pd.read_excel(folder_path+file_6, sheet_name=1, header=3)

# Create name change dictionary
name_change_dict = {}
for i in range(0, (no_of_cols*no_of_years)):
    name_change_dict[df_2021.columns[i+3]] = col_list[i]
    
# Rename columns
df_2021.rename(name_change_dict, axis=1, inplace=True)

# Removing Brand Names leading and trailing whitespace
df_2021['Brand Name'] = df_2021['Brand Name'].apply(lambda x: x.strip())
df_2021['Generic Name'] = df_2021['Generic Name'].apply(lambda x: x.strip())

# Divide datasets
common_columns = ['Brand Name', 'Generic Name']
df_2021_2017 = df_2021.iloc[:][common_columns+[i for i in df_2021.columns if '2017' in i][:-1]]
df_2021_2018 = df_2021.iloc[:][common_columns+[i for i in df_2021.columns if '2018' in i]]
df_2021_2019 = df_2021.iloc[:][common_columns+[i for i in df_2021.columns if '2019' in i]]
df_2021_2020 = df_2021.iloc[:][common_columns+[i for i in df_2021.columns if '2020' in i][:-1]]
df_2021_2021 = df_2021.iloc[:][common_columns+[i for i in df_2021.columns if '2021' in i][:-2]]

df_2021.head()
# Out:
#                        Brand Name                    Generic Name  \
# 0        1st Tier Unifine Pentips            Pen Needle, Diabetic
# 1   1st Tier Unifine Pentips Plus            Pen Needle, Diabetic
# 2                        Abacavir                Abacavir Sulfate
# 3             Abacavir-Lamivudine     Abacavir Sulfate/Lamivudine
# 4  Abacavir-Lamivudine-Zidovudine  Abacavir/Lamivudine/Zidovudine
#
#    Number of Manufacturers Total Spending_2017 Total Dosage Units_2017  \
# 0                        1           217938.04                 1014318
# 1                        1           402124.68                 1850703
# 2                        7         13386250.08                 3189707
# 3                        5         33787876.94                 1730418
# 4                        1         10158493.71                  468341
#
#   Total Claims_2017 Total Beneficiaries_2017  \
# 0              8595                     3025
# 1             15403                     5967
# 2             48283                     8090
# 3             55234                    10465
# 4              7451                      971
#
#   Average Spending Per Dosage Unit (Weighted)_2017  \
# 0                                             0.22
# 1                                             0.22
# 2                                             4.30
# 3                                            19.42
# 4                                            21.69
#
#   Average Spending Per Claim_2017 Average Spending Per Beneficiary_2017  \
# 0                           25.36                                 72.05
# 1                           26.11                                 67.39
# 2                          277.25                               1654.67
# 3                          611.72                               3228.66
# 4                         1363.37                              10461.89
#
#   Outlier Flag_2017 Total Spending_2018 Total Dosage Units_2018  \
# 0                 0           167193.78                  761658
# 1                 0           369402.85                 1813908
# 2                 0         10685287.61                 3041773
# 3                 0         18265777.87                 1669835
# 4                 0          6955321.12                  330735
#
#   Total Claims_2018 Total Beneficiaries_2018  \
# 0              6538                     2341
# 1             14931                     5674
# 2             40513                     7359
# 3             52728                     8681
# 4              5298                      710
#
#   Average Spending Per Dosage Unit (Weighted)_2018  \
# 0                                             0.22
# 1                                             0.20
# 2                                             4.03
# 3                                            10.95
# 4                                            21.03
#
#   Average Spending Per Claim_2018 Average Spending Per Beneficiary_2018  \
# 0                           25.57                                 71.42
# 1                           24.74                                 65.10
# 2                          263.75                               1452.00
# 3                          346.42                               2104.11
# 4                         1312.82                               9796.23
#
#   Outlier Flag_2018 Total Spending_2019 Total Dosage Units_2019  \
# 0                 0           139201.68                  642471
# 1                 0           343031.42                 1830596
# 2                 0         10126697.39                 3319967
# 3                 1         18502608.41                 1620774
# 4                 0          4849598.99                  225020
#
#   Total Claims_2019 Total Beneficiaries_2019  \
# 0              5392                     1878
# 1             14581                     5319
# 2             42694                     6085
# 3             47977                     6423
# 4              3648                      493
#
#   Average Spending Per Dosage Unit (Weighted)_2019  \
# 0                                             0.22
# 1                                             0.19
# 2                                             3.48
# 3                                            11.41
# 4                                            21.55
#
#   Average Spending Per Claim_2019 Average Spending Per Beneficiary_2019  \
# 0                           25.82                                 74.12
# 1                           23.53                                 64.49
# 2                          237.19                               1664.21
# 3                          385.66                               2880.68
# 4                         1329.39                               9836.91
#
#   Outlier Flag_2019 Total Spending_2020 Total Dosage Units_2020  \
# 0                 0           118923.24                  547006
# 1                 0           210217.15                 1046616
# 2                 0          9202476.64                 2960946
# 3                 0         14695662.65                 1365885
# 4                 0          2085404.63                   96333
#
#   Total Claims_2020 Total Beneficiaries_2020  \
# 0              4457                     1595
# 1              8408                     3905
# 2             37136                     5068
# 3             37355                     4752
# 4              1585                      290
#
#   Average Spending Per Dosage Unit (Weighted)_2020  \
# 0                                             0.22
# 1                                             0.20
# 2                                             3.49
# 3                                            10.77
# 4                                            21.65
#
#   Average Spending Per Claim_2020 Average Spending Per Beneficiary_2020  \
# 0                           26.68                                 74.56
# 1                           25.00                                 53.83
# 2                          247.80                               1815.80
# 3                          393.41                               3092.52
# 4                         1315.71                               7191.05
#
#   Outlier Flag_2020  Total Spending_2021  Total Dosage Units_2021  \
# 0                 0            102280.76                459384.00
# 1                 0            131927.33                566872.00
# 2                 0           7038593.83               2501447.00
# 3                 0           9658297.01               1150073.00
# 4                 0            146795.20                  7002.00
#
#    Total Claims_2021 Total Beneficiaries_2021  \
# 0               3708                     1313
# 1               4564                     1766
# 2              30540                     4254
# 3              30251                     4032
# 4                118                       32
#
#    Average Spending Per Dosage Unit (Weighted)_2021  \
# 0                                              0.22
# 1                                              0.23
# 2                                              3.19
# 3                                              8.40
# 4                                             20.96
#
#    Average Spending Per Claim_2021 Average Spending Per Beneficiary_2021  \
# 0                            27.58                                 77.90
# 1                            28.91                                 74.70
# 2                           230.47                               1654.58
# 3                           319.27                               2395.41
# 4                          1244.03                               4587.35
#
#    Outlier Flag_2021 Change in Average Spending Per Dosage Unit (2020-2021)  \
# 0                  0                                               0.02
# 1                  0                                               0.16
# 2                  0                                              -0.09
# 3                  1                                              -0.22
# 4                  0                                              -0.03
#
#   Annual Growth Rate in Average Spending Per Dosage Unit (2017-2021)
# 0                                               0.01
# 1                                               0.02
# 2                                              -0.07
# 3                                              -0.19
# 4                                              -0.01

# %% [markdown]
# ### Process year 2022

# %%
col_names = ['Total Spending', 'Total Dosage Units', 'Total Claims', 'Total Beneficiaries',
            'Average Spending Per Dosage Unit (Weighted)', 'Average Spending Per Claim',
            'Average Spending Per Beneficiary', 'Outlier Flag']
no_of_cols = 8
no_of_years = 5
current_year = 2022
starting_year = current_year - 4

# Generating future column names
col_list = []
for i in range(0, (no_of_cols*no_of_years)):
    if i % no_of_cols == 0 and i != 0:
        starting_year += 1
        
    col_list.append(col_names[i%no_of_cols]+"_"+str(starting_year))

# Read the Dataframe
df_2022 = pd.read_excel(folder_path+file_7, sheet_name=1, header=3)

# Create name change dictionary
name_change_dict = {}
for i in range(0, (no_of_cols*no_of_years)):
    name_change_dict[df_2022.columns[i+3]] = col_list[i]
    
# Rename columns
df_2022.rename(name_change_dict, axis=1, inplace=True)

# Removing Brand Names leading and trailing whitespace
df_2022['Brand Name'] = df_2022['Brand Name'].apply(lambda x: x.strip())
df_2022['Generic Name'] = df_2022['Generic Name'].apply(lambda x: x.strip())

# Divide datasets
common_columns = ['Brand Name', 'Generic Name']
df_2022_2018 = df_2022.iloc[:][common_columns+[i for i in df_2022.columns if '2018' in i][:-1]]
df_2022_2019 = df_2022.iloc[:][common_columns+[i for i in df_2022.columns if '2019' in i]]
df_2022_2020 = df_2022.iloc[:][common_columns+[i for i in df_2022.columns if '2020' in i]]
df_2022_2021 = df_2022.iloc[:][common_columns+[i for i in df_2022.columns if '2021' in i][:-1]]
df_2022_2022 = df_2022.iloc[:][common_columns+[i for i in df_2022.columns if '2022' in i][:-2]]

df_2022.head()
# Out:
#                        Brand Name                    Generic Name  \
# 0        1st Tier Unifine Pentips            Pen Needle, Diabetic
# 1   1st Tier Unifine Pentips Plus            Pen Needle, Diabetic
# 2                        Abacavir                Abacavir Sulfate
# 3             Abacavir-Lamivudine     Abacavir Sulfate/Lamivudine
# 4  Abacavir-Lamivudine-Zidovudine  Abacavir/Lamivudine/Zidovudine
#
#    Number of Manufacturers Total Spending_2018 Total Dosage Units_2018  \
# 0                        1           167193.78                  761658
# 1                        1           369402.85                 1813908
# 2                        6         10653423.32                 3034767
# 3                        4         15957795.55                 1429260
# 4                        1          6955321.12                  330735
#
#   Total Claims_2018 Total Beneficiaries_2018  \
# 0              6538                     2341
# 1             14931                     5674
# 2             40388                     7359
# 3             45575                     8681
# 4              5298                      710
#
#   Average Spending Per Dosage Unit (Weighted)_2018  \
# 0                                             0.22
# 1                                             0.20
# 2                                             4.03
# 3                                            11.16
# 4                                            21.03
#
#   Average Spending Per Claim_2018 Average Spending Per Beneficiary_2018  \
# 0                           25.57                                 71.42
# 1                           24.74                                 65.10
# 2                          263.78                               1447.67
# 3                          350.14                               1838.24
# 4                         1312.82                               9796.23
#
#   Outlier Flag_2018 Total Spending_2019 Total Dosage Units_2019  \
# 0                 0           139201.68                  642471
# 1                 0           343031.42                 1830596
# 2                 0         10119967.63                 3318767
# 3                 1         16480869.86                 1448269
# 4                 0          4849598.99                  225020
#
#   Total Claims_2019 Total Beneficiaries_2019  \
# 0              5392                     1878
# 1             14581                     5319
# 2             42673                     6085
# 3             42663                     6423
# 4              3648                      493
#
#   Average Spending Per Dosage Unit (Weighted)_2019  \
# 0                                             0.22
# 1                                             0.19
# 2                                             3.48
# 3                                            11.37
# 4                                            21.55
#
#   Average Spending Per Claim_2019 Average Spending Per Beneficiary_2019  \
# 0                           25.82                                 74.12
# 1                           23.53                                 64.49
# 2                          237.15                               1663.10
# 3                          386.30                               2565.91
# 4                         1329.39                               9836.91
#
#   Outlier Flag_2019 Total Spending_2020 Total Dosage Units_2020  \
# 0                 0           118923.24                  547006
# 1                 0           210217.15                 1046616
# 2                 0          9198597.07                 2960286
# 3                 0         11265372.88                  996520
# 4                 0          2085404.63                   96333
#
#   Total Claims_2020 Total Beneficiaries_2020  \
# 0              4457                     1595
# 1              8408                     3905
# 2             37119                     5068
# 3             27766                     4752
# 4              1585                      290
#
#   Average Spending Per Dosage Unit (Weighted)_2020  \
# 0                                             0.22
# 1                                             0.20
# 2                                             3.49
# 3                                            11.28
# 4                                            21.65
#
#   Average Spending Per Claim_2020 Average Spending Per Beneficiary_2020  \
# 0                           26.68                                 74.56
# 1                           25.00                                 53.83
# 2                          247.81                               1815.03
# 3                          405.73                               2370.66
# 4                         1315.71                               7191.05
#
#   Outlier Flag_2020 Total Spending_2021 Total Dosage Units_2021  \
# 0                 0           102280.76                  459384
# 1                 0           131927.33                  566872
# 2                 0          7036063.99                 2500817
# 3                 0          9294117.32                 1104102
# 4                 0           146795.20                    7002
#
#   Total Claims_2021 Total Beneficiaries_2021  \
# 0              3708                     1313
# 1              4564                     1766
# 2             30527                     4254
# 3             29168                     4032
# 4               118                       32
#
#   Average Spending Per Dosage Unit (Weighted)_2021  \
# 0                                             0.22
# 1                                             0.23
# 2                                             3.19
# 3                                             8.42
# 4                                            20.96
#
#   Average Spending Per Claim_2021 Average Spending Per Beneficiary_2021  \
# 0                           27.58                                 77.90
# 1                           28.91                                 74.70
# 2                          230.49                               1653.99
# 3                          318.64                               2305.09
# 4                         1244.03                               4587.35
#
#   Outlier Flag_2021  Total Spending_2022  Total Dosage Units_2022  \
# 0                 0             70039.61                310304.00
# 1                 0            114601.54                486206.00
# 2                 0           6945563.71               2035106.00
# 3                 1          11966266.63                990318.00
# 4                 0             68772.61                  3150.00
#
#    Total Claims_2022 Total Beneficiaries_2022  \
# 0               2501                     1147
# 1               3846                     1474
# 2              24317                     3452
# 3              25001                     3427
# 4                 59                       15
#
#    Average Spending Per Dosage Unit (Weighted)_2022  \
# 0                                              0.23
# 1                                              0.24
# 2                                              3.87
# 3                                             12.04
# 4                                             21.83
#
#    Average Spending Per Claim_2022 Average Spending Per Beneficiary_2022  \
# 0                            28.00                                 61.06
# 1                            29.80                                 77.75
# 2                           285.63                               2012.04
# 3                           478.63                               3491.76
# 4                          1165.64                               4584.84
#
#   Outlier Flag_2022 Change in Average Spending Per Dosage Unit (2021-2022)  \
# 0                 0                                               0.01
# 1                 0                                               0.01
# 2                 0                                               0.21
# 3                 0                                               0.43
# 4                 0                                               0.04
#
#   Annual Growth Rate in Average Spending Per Dosage Unit (2018-2022)
# 0                                               0.01
# 1                                               0.04
# 2                                              -0.01
# 3                                               0.02
# 4                                               0.01

# %%
def merge_dataframes(list_of_dfs):
    return pd.concat(list_of_dfs).drop_duplicates(subset=['Brand Name', 'Generic Name'], 
                                                  keep='last').reset_index(drop=True)

df_2012_merged = df_2016_2012.copy()
df_2013_merged = merge_dataframes([df_2016_2013, df_2017_2013])
df_2014_merged = merge_dataframes([df_2016_2014, df_2017_2014, df_2018_2014])
df_2015_merged = merge_dataframes([df_2016_2015, df_2017_2015, df_2018_2015, df_2019_2015])
df_2016_merged = merge_dataframes([df_2016_2016, df_2017_2016, df_2018_2016, df_2019_2016, df_2020_2016])
df_2017_merged = merge_dataframes([df_2017_2017, df_2018_2017, df_2019_2017, df_2020_2017, df_2021_2017])
df_2018_merged = merge_dataframes([df_2018_2018, df_2019_2018, df_2020_2018, df_2021_2018, df_2022_2018])
df_2019_merged = merge_dataframes([df_2019_2019, df_2020_2019, df_2021_2019, df_2022_2019])
df_2020_merged = merge_dataframes([df_2020_2020, df_2021_2020, df_2022_2020])
df_2021_merged = merge_dataframes([df_2021_2021, df_2022_2021])
df_2022_merged = df_2022_2022.copy()

# %%
# Merge all the dataframes
# Consider only the latest dataframe for each year
list_of_dfs = [
    df_2022_merged, df_2021_merged, df_2020_merged, df_2019_merged, df_2018_merged,
    df_2017_merged, df_2016_merged, df_2015_merged, df_2014_merged, df_2013_merged,
    df_2012_merged
]

# Outer join all dataframes
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Brand Name', 'Generic Name'],
                                            how='outer'), list_of_dfs[::-1])

# %%
(df_merged==0).all(axis=1).any()
# Out:
# False

# %%
df_merged.head()
# Out:
#                        Brand Name                    Generic Name  \
# 0        1st Tier Unifine Pentips            Pen Needle, Diabetic
# 1   1st Tier Unifine Pentips Plus            Pen Needle, Diabetic
# 2                        Abacavir                Abacavir Sulfate
# 3  Abacavir-Lamivudine-Zidovudine  Abacavir/Lamivudine/Zidovudine
# 4                         Abelcet    Amphotericin B Lipid Complex
#
#   Total Spending_2012 Total Dosage Units_2012 Total Claims_2012  \
# 0            75374.20                  403344              3468
# 1
# 2            10332426                 1329746             20884
# 3
# 4           585453.65                   59917               465
#
#   Total Beneficiaries_2012 Average Spending Per Dosage Unit (Weighted)_2012  \
# 0                     1249                                             0.19
# 1
# 2                     5616                                             7.77
# 3
# 4                      109                                             9.77
#
#   Average Spending Per Claim_2012 Average Spending Per Beneficiary_2012  \
# 0                           21.73                                 60.35
# 1
# 2                          494.75                               1839.82
# 3
# 4                         1259.04                               5371.13
#
#   Total Spending_2013 Total Dosage Units_2013 Total Claims_2013  \
# 0            94537.70                  518920              4376
# 1
# 2            26828850                 3747816             58827
# 3            78230.03                    3473                49
# 4           582002.93                   56574               435
#
#   Total Beneficiaries_2013 Average Spending Per Dosage Unit (Weighted)_2013  \
# 0                     1620                                             0.18
# 1
# 2                     8346                                             7.16
# 3                       49                                            22.53
# 4                      130                                            10.29
#
#   Average Spending Per Claim_2013 Average Spending Per Beneficiary_2013  \
# 0                           21.60                                 58.36
# 1
# 2                          456.06                               3214.58
# 3                         1596.53                               1596.53
# 4                         1337.94                               4476.95
#
#   Total Spending_2014 Total Dosage Units_2014 Total Claims_2014  \
# 0           123941.34                  680820              5650
# 1            54091.29                  269725              2275
# 2         27941765.03              4337914.99             68187
# 3         17167220.41                  766713             12201
# 4           514240.20                   55290               419
#
#   Total Beneficiaries_2014 Average Spending Per Dosage Unit (Weighted)_2014  \
# 0                     2097                                             0.18
# 1                     1289                                             0.20
# 2                     9076                                             6.44
# 3                     1821                                            22.39
# 4                      116                                             9.30
#
#   Average Spending Per Claim_2014 Average Spending Per Beneficiary_2014  \
# 0                           21.94                                 59.10
# 1                           23.78                                 41.96
# 2                          409.78                               3078.64
# 3                         1407.03                               9427.36
# 4                         1227.30                               4433.11
#
#   Outlier Flag_2014 Total Spending_2015 Total Dosage Units_2015  \
# 0                 0           134200.53                  718948
# 1                 0           197091.75                  986070
# 2                 0         24519295.76                 4413607
# 3                 0         16626213.80                  759933
# 4                 0           552847.75                   47600
#
#   Total Claims_2015 Total Beneficiaries_2015  \
# 0              5802                     2290
# 1              7889                     4330
# 2             69019                     9319
# 3             12216                     1621
# 4               439                      102
#
#   Average Spending Per Dosage Unit (Weighted)_2015  \
# 0                                             0.19
# 1                                             0.20
# 2                                             5.56
# 3                                            21.88
# 4                                            11.61
#
#   Average Spending Per Claim_2015 Average Spending Per Beneficiary_2015  \
# 0                           23.13                                 58.60
# 1                           24.98                                 45.52
# 2                          355.25                               2631.11
# 3                         1361.02                              10256.76
# 4                         1259.33                               5420.08
#
#   Outlier Flag_2015 Total Spending_2016 Total Dosage Units_2016  \
# 0                 0           216273.87                 1052113
# 1                 0           378040.97                 1750907
# 2                 0         19337054.97                 4253483
# 3                 0         12787721.57                  608455
# 4                 0           752938.84                   85650
#
#   Total Claims_2016 Total Beneficiaries_2016  \
# 0              8913                     3428
# 1             14610                     6564
# 2             66523                     9008
# 3              9768                     1333
# 4               476                      140
#
#   Average Spending Per Dosage Unit (Weighted)_2016  \
# 0                                             0.21
# 1                                             0.22
# 2                                             4.55
# 3                                            21.02
# 4                                             8.79
#
#   Average Spending Per Claim_2016 Average Spending Per Beneficiary_2016  \
# 0                           24.26                                 63.09
# 1                           25.88                                 57.59
# 2                          290.68                               2146.65
# 3                         1309.14                               9593.19
# 4                         1581.80                               5378.13
#
#   Outlier Flag_2016 Total Spending_2017 Total Dosage Units_2017  \
# 0                 0           217938.04                 1014318
# 1                 0           402124.68                 1850703
# 2                 0         13386250.08                 3189707
# 3                 0         10158493.71                  468341
# 4                 1           675695.03                   68490
#
#   Total Claims_2017 Total Beneficiaries_2017  \
# 0              8595                     3025
# 1             15403                     5967
# 2             48283                     8090
# 3              7451                      971
# 4               420                      137
#
#   Average Spending Per Dosage Unit (Weighted)_2017  \
# 0                                             0.22
# 1                                             0.22
# 2                                             4.30
# 3                                            21.69
# 4                                             9.87
#
#   Average Spending Per Claim_2017 Average Spending Per Beneficiary_2017  \
# 0                           25.36                                 72.05
# 1                           26.11                                 67.39
# 2                          277.25                               1654.67
# 3                         1363.37                              10461.89
# 4                         1608.80                               4932.08
#
#   Outlier Flag_2017 Total Spending_2018 Total Dosage Units_2018  \
# 0                 0           167193.78                  761658
# 1                 0           369402.85                 1813908
# 2                 0         10653423.32                 3034767
# 3                 0          6955321.12                  330735
# 4                 0           766166.41               101857.38
#
#   Total Claims_2018 Total Beneficiaries_2018  \
# 0              6538                     2341
# 1             14931                     5674
# 2             40388                     7359
# 3              5298                      710
# 4               620                      205
#
#   Average Spending Per Dosage Unit (Weighted)_2018  \
# 0                                             0.22
# 1                                             0.20
# 2                                             4.03
# 3                                            21.03
# 4                                             7.52
#
#   Average Spending Per Claim_2018 Average Spending Per Beneficiary_2018  \
# 0                           25.57                                 71.42
# 1                           24.74                                 65.10
# 2                          263.78                               1447.67
# 3                         1312.82                               9796.23
# 4                         1235.75                               3737.40
#
#   Outlier Flag_2018 Total Spending_2019 Total Dosage Units_2019  \
# 0                 0           139201.68                  642471
# 1                 0           343031.42                 1830596
# 2                 0         10119967.63                 3318767
# 3                 0          4849598.99                  225020
# 4                 0           618247.30                  120570
#
#   Total Claims_2019 Total Beneficiaries_2019  \
# 0              5392                     1878
# 1             14581                     5319
# 2             42673                     6085
# 3              3648                      493
# 4               777                      226
#
#   Average Spending Per Dosage Unit (Weighted)_2019  \
# 0                                             0.22
# 1                                             0.19
# 2                                             3.48
# 3                                            21.55
# 4                                             5.13
#
#   Average Spending Per Claim_2019 Average Spending Per Beneficiary_2019  \
# 0                           25.82                                 74.12
# 1                           23.53                                 64.49
# 2                          237.15                               1663.10
# 3                         1329.39                               9836.91
# 4                          795.69                               2735.61
#
#   Outlier Flag_2019 Total Spending_2020 Total Dosage Units_2020  \
# 0                 0           118923.24                  547006
# 1                 0           210217.15                 1046616
# 2                 0          9198597.07                 2960286
# 3                 0          2085404.63                   96333
# 4                 0           637913.66                  124320
#
#   Total Claims_2020 Total Beneficiaries_2020  \
# 0              4457                     1595
# 1              8408                     3905
# 2             37119                     5068
# 3              1585                      290
# 4               826                      238
#
#   Average Spending Per Dosage Unit (Weighted)_2020  \
# 0                                             0.22
# 1                                             0.20
# 2                                             3.49
# 3                                            21.65
# 4                                             5.13
#
#   Average Spending Per Claim_2020 Average Spending Per Beneficiary_2020  \
# 0                           26.68                                 74.56
# 1                           25.00                                 53.83
# 2                          247.81                               1815.03
# 3                         1315.71                               7191.05
# 4                          772.29                               2680.31
#
#   Outlier Flag_2020 Total Spending_2021 Total Dosage Units_2021  \
# 0                 0           102280.76                  459384
# 1                 0           131927.33                  566872
# 2                 0          7036063.99                 2500817
# 3                 0           146795.20                    7002
# 4                 0           504545.33                   97200
#
#   Total Claims_2021 Total Beneficiaries_2021  \
# 0              3708                     1313
# 1              4564                     1766
# 2             30527                     4254
# 3               118                       32
# 4               697                      199
#
#   Average Spending Per Dosage Unit (Weighted)_2021  \
# 0                                             0.22
# 1                                             0.23
# 2                                             3.19
# 3                                            20.96
# 4                                             5.19
#
#   Average Spending Per Claim_2021 Average Spending Per Beneficiary_2021  \
# 0                           27.58                                 77.90
# 1                           28.91                                 74.70
# 2                          230.49                               1653.99
# 3                         1244.03                               4587.35
# 4                          723.88                               2535.40
#
#   Outlier Flag_2021  Total Spending_2022  Total Dosage Units_2022  \
# 0                 0             70039.61                310304.00
# 1                 0            114601.54                486206.00
# 2                 0           6945563.71               2035106.00
# 3                 0             68772.61                  3150.00
# 4                 0            297179.43                 53540.00
#
#    Total Claims_2022 Total Beneficiaries_2022  \
# 0            2501.00                     1147
# 1            3846.00                     1474
# 2           24317.00                     3452
# 3              59.00                       15
# 4             350.00                      113
#
#    Average Spending Per Dosage Unit (Weighted)_2022  \
# 0                                              0.23
# 1                                              0.24
# 2                                              3.87
# 3                                             21.83
# 4                                              5.55
#
#    Average Spending Per Claim_2022 Average Spending Per Beneficiary_2022  \
# 0                            28.00                                 61.06
# 1                            29.80                                 77.75
# 2                           285.63                               2012.04
# 3                          1165.64                               4584.84
# 4                           849.08                               2629.91
#
#   Outlier Flag_2022
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
df_merged.isna().sum()
# Out:
# Brand Name                                             0
# Generic Name                                           0
# Total Spending_2012                                 2469
# Total Dosage Units_2012                             2469
# Total Claims_2012                                   2469
# Total Beneficiaries_2012                            2483
# Average Spending Per Dosage Unit (Weighted)_2012    2469
# Average Spending Per Claim_2012                     2469
# Average Spending Per Beneficiary_2012               2483
# Total Spending_2013                                 2158
# Total Dosage Units_2013                             2158
# Total Claims_2013                                   2158
# Total Beneficiaries_2013                            2178
# Average Spending Per Dosage Unit (Weighted)_2013    2158
# Average Spending Per Claim_2013                     2158
# Average Spending Per Beneficiary_2013               2178
# Total Spending_2014                                 1673
# Total Dosage Units_2014                             1673
# Total Claims_2014                                   1673
# Total Beneficiaries_2014                            1599
# Average Spending Per Dosage Unit (Weighted)_2014    1673
# Average Spending Per Claim_2014                     1673
# Average Spending Per Beneficiary_2014               1723
# Outlier Flag_2014                                   2048
# Total Spending_2015                                 1432
# Total Dosage Units_2015                             1432
# Total Claims_2015                                   1432
# Total Beneficiaries_2015                            1366
# Average Spending Per Dosage Unit (Weighted)_2015    1432
# Average Spending Per Claim_2015                     1432
# Average Spending Per Beneficiary_2015               1497
# Outlier Flag_2015                                   1827
# Total Spending_2016                                 1277
# Total Dosage Units_2016                             1277
# Total Claims_2016                                   1277
# Total Beneficiaries_2016                            1212
# Average Spending Per Dosage Unit (Weighted)_2016    1277
# Average Spending Per Claim_2016                     1277
# Average Spending Per Beneficiary_2016               1351
# Outlier Flag_2016                                   1670
# Total Spending_2017                                 1351
# Total Dosage Units_2017                             1351
# Total Claims_2017                                   1351
# Total Beneficiaries_2017                            1335
# Average Spending Per Dosage Unit (Weighted)_2017    1351
# Average Spending Per Claim_2017                     1351
# Average Spending Per Beneficiary_2017               1453
# Outlier Flag_2017                                   1474
# Total Spending_2018                                 1243
# Total Dosage Units_2018                             1243
# Total Claims_2018                                   1243
# Total Beneficiaries_2018                            1288
# Average Spending Per Dosage Unit (Weighted)_2018    1243
# Average Spending Per Claim_2018                     1243
# Average Spending Per Beneficiary_2018               1395
# Outlier Flag_2018                                   1254
# Total Spending_2019                                 1199
# Total Dosage Units_2019                             1199
# Total Claims_2019                                   1199
# Total Beneficiaries_2019                            1295
# Average Spending Per Dosage Unit (Weighted)_2019    1199
# Average Spending Per Claim_2019                     1199
# Average Spending Per Beneficiary_2019               1353
# Outlier Flag_2019                                   1204
# Total Spending_2020                                 1151
# Total Dosage Units_2020                             1151
# Total Claims_2020                                   1151
# Total Beneficiaries_2020                            1294
# Average Spending Per Dosage Unit (Weighted)_2020    1151
# Average Spending Per Claim_2020                     1151
# Average Spending Per Beneficiary_2020               1326
# Outlier Flag_2020                                   1156
# Total Spending_2021                                 1149
# Total Dosage Units_2021                             1149
# Total Claims_2021                                   1149
# Total Beneficiaries_2021                            1332
# Average Spending Per Dosage Unit (Weighted)_2021    1149
# Average Spending Per Claim_2021                     1149
# Average Spending Per Beneficiary_2021               1336
# Outlier Flag_2021                                   1155
# Total Spending_2022                                 1159
# Total Dosage Units_2022                             1159
# Total Claims_2022                                   1159
# Total Beneficiaries_2022                            1348
# Average Spending Per Dosage Unit (Weighted)_2022    1159
# Average Spending Per Claim_2022                     1159
# Average Spending Per Beneficiary_2022               1348
# Outlier Flag_2022                                   1172
# dtype: int64

# %%
# Making sure all columns are float
for col in df_merged.columns[2:]:
    df_merged[col].replace(r'^\s*$', None, regex=True, inplace=True)
    # df_merged[col] = df_merged[col].astype(np.float64)

# %%
# Remove drugs whose columns sum up to zero
df_merged = df_merged.loc[df_merged.sum(axis=1, numeric_only=True) != 0]

# %%
# Saving it in a CSV
df_merged.to_csv("wide_format_drugs_years.csv", index=False)
